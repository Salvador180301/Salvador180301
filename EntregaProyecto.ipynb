# %% [markdown]
# ## Entrega Proyecto
# ### Salvador Ortega Robles A01366568
# ### Pensamiento Computacional para Ingeniería
# ### Germán Domínguez Solís
# ### 17 de Octubre del 2021

# %% [markdown]
# https://colab.research.google.com/drive/1y7GTOupP7kWU4hrkanN8J5Oe6c3tl7LD#scrollTo=6jvAOsPxX6V9

# %% [markdown]
# Debido al surgimiento y esparcimiento del virus COVID-19, en México las enfermedades como la obesidad, la diabetes, la hipertensión, entre muchas otras, causadas por los malos hábitos alimenticios y la poca actividad física de la comunidad,  han expuesto la incapacidad de la sociedad mexicana para alcanzar un estado de bienestar físico y mental.
# Sin duda, la pandemia del coronavirus generó que las brechas ya existentes  en nuestra sociedad hayan aumentado y nos ha enseñado como la relación entre la salud y el logro de un futuro sostenible, exponiendo las concecuencias que tiene mantener el estilo de vida que llevamos sobre nuestro bienestar y el medio ambiente, así como la generación de pobreza y desigualdad, efectos que se ven sobretodo en este importante ámbito. Las condiciones en que las personas viven, incluidos factores como la pobreza, la exclusión, la desigualdad, el estatus social, la vivienda y las circunstancias políticas y ambientales, inciden notablemente en su salud y bienestar.
#
# Gracias a programas como el que realizaremos, es que se pueden generar espacios en la red para que la gente tenga acceso a información que los pueda llevar a un grado importante de bienestar, con consejos y guías que les permitirán llevar estilos de vida saludables que involucren todos los aspectos del bienestar.
#
# La programación juega un papel importantísimo e integral en el desarrollo de las condiciones necesarias para que las personas puedan llevar a cabo acciones que aumenten su bienestar, generando estilos de vida que los mantengan estables y con energía para llevar a cabo todo tipo de actividades que enriquezcan su vida y los encaminen a cumplir sus metas, objetivos y sueños, además de la facilidad y eficacia que tiene para difundir información esencial, la programación permite tener control sobre tu avance hacia un estilo de vida saludable y pleno.
#
# Es a través de este programa que una empresa puede conocer el estilo de vida de sus empleados y atacar aquellas partes de este que no le generan un bienestar, pudiendo asi mejorar la calidad de vida de aquellos que realizan una ardua labor para el crecimiento y expansión de la industria.
#
# El darle seguimiento y una constante revisión al estado físico de tus empleados te abre una ventana importante de posibilidades para maximizar su rendimiento laborar, el conocer el nivel de bienestar de tus trabajadores te permitirá tener un acercamiento enfocado a las necesidades de estos, con lo que puedes generar actividades generales o específicas para aumentar su bienestar.

# %% [markdown]
# ### def alta_empleado():
#   La primera función genera los datos iniciales de la matriz empleados, en ella se agrega la información general de cada empleado y con la cual se va a trabajar para mejorar la calidad de vida de los trabajadores, se piden los datos pertinentes de cada uno y se juntan todos en una lista que posteriormente se adhiere a la matriz.
#
# ### def calcular_imc():
#  La funcion que calcula el imc de los empleados comienza generando un contador que nos servirá para calcular el porcentaje de cada rango del indicador de masa, despues llama al peso y altura de cada empleado para realizar la operación y orgaizarlos en níveles que van desde delgadez severa a obesidad tipo III.
#
# ### def actualizar_empleado():
#   "actualizar_empleado" Le permite al usuario cambiar uno por uno los datos de el empleado deseado, se le pide que ingrese el id de este y con un "n-1" el progama busca a la lista que se encuentra en esa posición y comienza a preguntar si desea cambiar los valores y si está seguro el usuario de cambiarlo y en caso de que si el programa agrega el cambio. En caso de que el id no se encuentre registrado imprime un mensaje que lo menciona y pide ingresar uno que si lo esté
#
# ### def consultar_empleado():
#   Esta función nos permite llamar los datos de un empleado, esta pide el id del trabajador y si este esta dentro de la matriz, imprime todos sus datos. En caso de que el id no se encuentre registrado imprime un mensaje que lo menciona y pide ingresar uno que si lo esté.
#
#
# ### def crear_reporte_empleado():
#   Al llamar esta función se crea una interfaz organizada donde encontramos todos los datos de todos los empleados asi como las estadísticas generadas a partir de estos.
#
# ### def salir():
#   Con esta función el usuario puede cerrar el programa
#
# ### def grabar_archivo():
#   Esta función convierte a strings todos los datos en cada lista de la matriz y los agrega a un archivo.

# %% [markdown]
# Durante este proyecto confirme que existen miles de posibilidades para todo evento problemática o suceso que nos acercan aún más a la solución del mismo, por o que es importante generar espacios donde todas las ideas se compartan y se pongan a prueba para encontrar cual de ellas es la más conveniente o eficaz, aprendí que el mantener aplicado tu conocimiento y a prueba puede generarte ventajas al resolver problemas específicos y que si buscas una forma de hacerlo divertido e intetesante estás un paso adelante en la resolución del problema
#
# El buscar redes de apoyo para solucionar está problemática considero que es una de las cosas que mejor hice durante la realización de este proyecto debido a la cantidad de conocimiento adquirido de un mismo tema, además de la facilidad con la que pude solventar los problemas a los que me enfrentaba y no hay duda alguna que e haberle podido dedicar más tiempo y no hacerlo fue el error más grande que cometí ya que solo me generaba estrés y preocupación, cosas que pueden bloquear el sentido común y tu capacidad de análisis.

# %%
def alta_empleado(empleados):
  print("1. Alta de Empleado")
  
  
  id = int(input("Ingresa el ID del empleado: "))
  nombre = input("Ingresa el nombre del empleado: ")
  edad = int(input("Ingresa la edad del empleado: "))
  peso = float(input("Ingresa el peso del empleado en kilogramos: "))
  estatura = float(input("Ingresa la estatura en metros del empleado: "))
  diabetes = int(input("Diabetes 1. Si 2. No "))
  hipertension = int(input("Hipertensión 1. Si 2. No "))
  cardiovascular = int(input("Enfermedades cardiovasculares 1.Si 2.No "))
  cancer = int(input("Cáncer 1.Si 2.No "))
  tabaquismo = int(input("Tabaquismo 1.Si 2.No "))
  vacuna = int(input("Vacuna Covid 19 1.Si 2.No ")) 


  empleado = [id, nombre, edad, peso, estatura, diabetes, hipertension, cardiovascular, cancer, tabaquismo, vacuna]
  print(empleado)
    
  empleados.append(empleado)
        
  print(empleados)
  return empleados



def calcular_imc():
 
  contador_imc = [0, 0, 0, 0, 0, 0, 0, 0]
  etiqueta = ["Delgadez severa", "Delgadez moderada", "Delgadez aceptable", "Normal", "Pre-obeso", "Obeso tipo I", "Obeso tipo II", "Obeso tipo III"]

  print(f'{"Clasificación IMC":<20}{"IMC":<10}{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Altura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  
  for empleado in empleados:

    id, nombre, edad, peso, altura, diabetes, hipertension, corazon, cancer, tabaquismo, vacuna_covid = empleado

    imc = float(empleado[3]) / (float(empleado[4]) ** 2)
    
    if imc < 16:
      clasificacion = etiqueta[0]
      contador_imc[0] += 1
    elif 16 <= imc and imc < 17:
      clasificacion = etiqueta[1]
      contador_imc[1] += 1
    elif 17 <= imc and imc < 18.50:
      clasificacion = etiqueta[2]
      contador_imc[2] += 1
    elif 18.50 <= imc and imc < 25:
      clasificacion = etiqueta[3]
      contador_imc[3] += 1
    elif 25 <= imc and imc < 30:
      clasificacion = etiqueta[4]
      contador_imc[4] += 1
    elif 30 <= imc and imc < 35:
      clasificacion = etiqueta[5]
      contador_imc[5] += 1
    elif 35 <= imc and imc < 40:
      clasificacion = etiqueta[6]
      contador_imc[6] += 1
    else:
      clasificacion = etiqueta[7]
      contador_imc[7] += 1

   

def actualizar_empleado(empleados):
    print("Actualiza un empleado")
    n = int(input('ingresa el id '))
    if n <= (len(empleados)):
        for i in range(len(empleados[n-1])):
            print(empleados[n-1][i])
            hold = input('ingresa el valor a cambiar, presiona enter para terminar de actualizar los datos: ')
            
            temp_empleado = empleados[n-1].copy()
            
            if hold == " ":
              print("Ha terminado de actualizar los datos")
            elif hold != '':
              if i == 0:
                temp_empleado[i] = int(hold)
              elif i == 1:
                temp_empleado[i] = (hold)
              elif i == 2:
                temp_empleado[i] = int(hold)
              elif i == 3:
                temp_empleado[i] = float(hold)
              elif i == 4:
                temp_empleado[i] = float(hold)
              elif i == 5:
                temp_empleado[i] = int(hold)
              elif i == 6:
                temp_empleado[i] = int(hold)
              elif i == 7:
                temp_empleado[i] = int(hold)
              elif i == 8:
                temp_empleado[i] = int(hold)
              elif i == 9:
                temp_empleado[i] = int(hold)
              elif i == 10:
                temp_empleado[i] = int(hold)


              check = input("estas seguro de los cambios s/n: ")
              if check == 's':
                empleados[n-1] = temp_empleado
              elif check == "n":
                print()
                
                
            
    else:
      print("Ingresa un ID válido")




def consultar_empleado(empleados):
  print("Consulta los datos de un empleado")
  n = int(input('ingresa el ID del empleado: '))
  if n <= (len(empleados)):
    print(empleados[n-1])
  else:
    print("Ingrese un ID correcto")
    return


def crear_reporte_empleado():

  contador_enfermedades = [0, 0, 0, 0, 0, 0]
  enfermedad = ["Diabetes", "Hipertensión", "Corazón", "Cáncer", "Tabaquismo", "Vacuna Covid"]

  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Altura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  
  for empleado in empleados:

    id, nombre, edad, peso, altura, diabetes, hipertension, corazon, cancer, tabaquismo, vacuna_covid = empleado

    if diabetes == "1":
      contador_enfermedades[0] += 1
    if hipertension == "1":
      contador_enfermedades[1] += 1
    if corazon == "1":
      contador_enfermedades[2] += 1
    if cancer == "1":
      contador_enfermedades[3] += 1
    if tabaquismo == "1":
      contador_enfermedades[4] += 1
    if vacuna_covid == "1":
      contador_enfermedades[5] += 1

    print(f'{id:<10}{nombre:<15}{peso:<10}{altura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Vacunado" if vacuna_covid == "1" else "____________":15}')
  
  print(f'\n{"Enfermedad":27}{"Cantidad":10}{"Porcentaje":<10}')

  lista = []
  for num in range(len(contador_enfermedades)):
    lista_temp = []
    lista_temp = [contador_enfermedades[num], enfermedad[num], round(contador_enfermedades[num] / len(empleados) * 100)]
    lista.append(lista_temp)
  
  lista.sort(reverse = True)

  for dato in lista:
    contador, enfermedad, porcentaje = dato
    print(f"{enfermedad:20} {contador:7} {porcentaje:10}%")

  print(f'{"Total de empleados:":<10} {len(empleados):<10}')
 
nombre_archivo = "empleados"
def grabar_archivo(nombre):

  with open(nombre_archivo, "w") as archivo:
    for empleado in empleados:
      empleado[0] = str(empleado[0])
      empleado[1] = str(empleado[1])
      empleado[2] = str(empleado[2])
      empleado[3] = str(empleado[3])
      empleado[4] = str(empleado[4])
      empleado[5] = str(empleado[5])
      empleado[6] = str(empleado[6])
      empleado[7] = str(empleado[7])
      empleado[8] = str(empleado[8])
      empleado[9] = str(empleado[9])
      empleado[10] = str(empleado[10])

      texto = ",".join(empleado)
      archivo.write(texto + "\n")

def leer_archivo(nombre):
  with open(nombre_archivo, "r") as archivo:
    contenido = archivo.readlines()
    for elemento in contenido:
      linea = elemento.split(",")
      empleados.append(linea)
  
empleados = leer_archivo(nombre_archivo)

def salir():
  print("Hasta luego")

def menu():

  print("Sistema de Salud y Bienestar del Empleado")
  print("1. Alta de Empleado")
  print("2. Calcular IMC del Empleado")
  print("3. Cambia Información del Empleado")
  print("4. Consulta un Empleado")
  print("5. Reporte de todos los Empleados")
  print("6. Salir")

def main():
  menu()
  global empleados
  empleados=[]
  
  while True:
    opcion = input("Teclea una opción: ")
    if opcion == "1":
     empleados = alta_empleado(empleados)
     grabar_archivo(nombre_archivo)
     leer_archivo(nombre_archivo)
    elif opcion == "2":
      calcular_imc(empleados)
      leer_archivo(nombre_archivo)
    elif opcion == "3":
     actualizar_empleado(empleados)
     grabar_archivo(nombre_archivo)
     leer_archivo(nombre_archivo)
    elif opcion == "4":
     consultar_empleado(empleados)
     leer_archivo(nombre_archivo)
    elif opcion == "5":
     reporte_empleados(empleados)
     leer_archivo(nombre_archivo)
    elif opcion == "6":
      salir()
      break
    else:
     print("Por favor teclee una opción correcta")
main()
